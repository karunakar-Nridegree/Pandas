# %% [markdown]
# Importing Pandas and as well as required Files from the Google ***Drive***

# %%
import pandas as pd

# %%
import random
age = []
height = []
weight = []
speed = []
for _ in range(100):
  age.append(random.randint(0,100))
  height.append(random.randint(0,100))
  weight.append(random.randint(0,100))
  speed.append(random.randint(0,100))

idata = {'Age':age,'Height':height,'Weight':weight,'Speed':speed}

# %%
idata
# Out:
# {'Age': [60,
#   77,
#   23,
#   68,
#   65,
#   32,
#   40,
#   30,
#   6,
#   19,
#   71,
#   34,
#   71,
#   53,
#   64,
#   98,
#   58,
#   31,
#   70,
#   60,
#   65,
#   50,
#   22,
#   59,
#   57,
#   69,
#   29,
#   34,
#   5,
#   31,
#   17,
#   75,
#   89,
#   39,
#   22,
#   64,
#   10,
#   1,
#   95,
#   43,
#   44,
#   91,
#   22,
#   63,
#   83,
#   71,
#   52,
#   77,
#   63,
#   64,
#   91,
#   6,
#   2,
#   90,
#   2,
#   74,
#   100,
#   50,
#   90,
#   91,
#   17,
#   11,
#   71,
#   93,
#   60,
#   43,
#   15,
#   65,
#   74,
#   53,
#   9,
#   73,
#   82,
#   2,
#   81,
#   61,
#   56,
#   94,
#   23,
#   90,
#   47,
#   89,
#   72,
#   62,
#   27,
#   39,
#   10,
#   91,
#   2,
#   23,
#   22,
#   71,
#   19,
#   47,
#   26,
#   80,
#   17,
#   12,
#   79,
#   53],
#  'Height': [8,
#   54,
#   67,
#   98,
#   20,
#   45,
#   14,
#   87,
#   23,
#   5,
#   96,
#   87,
#   62,
#   51,
#   69,
#   58,
#   99,
#   51,
#   49,
#   45,
#   48,
#   16,
#   26,
#   65,
#   73,
#   66,
#   74,
#   39,
#   12,
#   42,
#   6,
#   13,
#   10,
#   98,
#   51,
#   60,
#   41,
#   73,
#   58,
#   38,
#   97,
#   17,
#   49,
#   62,
#   8,
#   16,
#   64,
#   60,
#   88,
#   30,
#   5,
#   71,
#   92,
#   20,
#   93,
#   34,
#   47,
#   63,
#   19,
#   19,
#   56,
#   97,
#   7,
#   56,
#   2,
#   33,
#   40,
#   1,
#   50,
#   2,
#   11,
#   95,
#   91,
#   21,
#   63,
#   67,
#   26,
#   89,
#   2,
#   98,
#   23,
#   16,
#   47,
#   57,
#   54,
#   95,
#   26,
#   16,
#   96,
#   9,
#   9,
#   25,
#   88,
#   65,
#   72,
#   73,
#   5,
#   55,
#   99,
#   79],
#  'Weight': [5,
#   38,
#   99,
#   43,
#   67,
#   38,
#   64,
#   15,
#   100,
#   27,
#   48,
#   3,
#   19,
#   83,
#   38,
#   68,
#   44,
#   33,
#   53,
#   23,
#   37,
#   53,
#   90,
#   92,
#   75,
#   28,
#   59,
#   25,
#   88,
#   39,
#   35,
#   7,
#   44,
#   60,
#   88,
#   15,
#   47,
#   65,
#   65,
#   96,
#   50,
#   91,
#   3,
#   59,
#   12,
#   15,
#   74,
#   32,
#   52,
#   87,
#   46,
#   87,
#   43,
#   85,
#   90,
#   12,
#   97,
#   83,
#   41,
#   89,
#   73,
#   56,
#   32,
#   29,
#   18,
#   10,
#   20,
#   9,
#   54,
#   20,
#   54,
#   68,
#   53,
#   14,
#   8,
#   19,
#   67,
#   29,
#   33,
#   39,
#   88,
#   45,
#   87,
#   95,
#   66,
#   97,
#   20,
#   97,
#   88,
#   11,
#   26,
#   17,
#   56,
#   14,
#   73,
#   39,
#   64,
#   66,
#   24,
#   6],
#  'Speed': [97,
#   97,
#   71,
#   73,
#   69,
#   90,
#   94,
#   32,
#   86,
#   86,
#   64,
#   81,
#   26,
#   33,
#   87,
#   89,
#   64,
#   96,
#   100,
#   90,
#   93,
#   9,
#   5,
#   93,
#   41,
#   24,
#   31,
#   67,
#   22,
#   36,
#   10,
#   43,
#   29,
#   91,
#   0,
#   52,
#   8,
#   90,
#   94,
#   49,
#   65,
#   80,
#   85,
#   15,
#   93,
#   78,
#   48,
#   8,
#   7,
#   4,
#   29,
#   96,
#   55,
#   62,
#   2,
#   100,
#   0,
#   61,
#   89,
#   13,
#   97,
#   24,
#   23,
#   68,
#   86,
#   74,
#   88,
#   9,
#   60,
#   14,
#   37,
#   91,
#   98,
#   52,
#   39,
#   98,
#   5,
#   20,
#   33,
#   56,
#   74,
#   59,
#   32,
#   77,
#   29,
#   65,
#   68,
#   30,
#   77,
#   84,
#   66,
#   8,
#   26,
#   14,
#   13,
#   25,
#   65,
#   39,
#   65,
#   26]}

# %%
df=pd.DataFrame(idata)

# %%
df
# Out:
#     Age  Height  Weight  Speed
# 0    60       8       5     97
# 1    77      54      38     97
# 2    23      67      99     71
# 3    68      98      43     73
# 4    65      20      67     69
# ..  ...     ...     ...    ...
# 95   80      73      39     25
# 96   17       5      64     65
# 97   12      55      66     39
# 98   79      99      24     65
# 99   53      79       6     26
#
# [100 rows x 4 columns]

# %%
df.head(12)
# Out:
#     Age  Height  Weight  Speed
# 0    60       8       5     97
# 1    77      54      38     97
# 2    23      67      99     71
# 3    68      98      43     73
# 4    65      20      67     69
# 5    32      45      38     90
# 6    40      14      64     94
# 7    30      87      15     32
# 8     6      23     100     86
# 9    19       5      27     86
# 10   71      96      48     64
# 11   34      87       3     81

# %%
df.tail(23)
# Out:
#     Age  Height  Weight  Speed
# 77   94      89      29     20
# 78   23       2      33     33
# 79   90      98      39     56
# 80   47      23      88     74
# 81   89      16      45     59
# 82   72      47      87     32
# 83   62      57      95     77
# 84   27      54      66     29
# 85   39      95      97     65
# 86   10      26      20     68
# 87   91      16      97     30
# 88    2      96      88     77
# 89   23       9      11     84
# 90   22       9      26     66
# 91   71      25      17      8
# 92   19      88      56     26
# 93   47      65      14     14
# 94   26      72      73     13
# 95   80      73      39     25
# 96   17       5      64     65
# 97   12      55      66     39
# 98   79      99      24     65
# 99   53      79       6     26

# %%
df[['Age','Height']]
# Out:
#     Age  Height
# 0    60       8
# 1    77      54
# 2    23      67
# 3    68      98
# 4    65      20
# ..  ...     ...
# 95   80      73
# 96   17       5
# 97   12      55
# 98   79      99
# 99   53      79
#
# [100 rows x 2 columns]

# %%
df.describe()
# Out:
#               Age      Height      Weight      Speed
# count  100.000000  100.000000  100.000000  100.00000
# mean    50.930000   48.670000   49.480000   54.16000
# std     28.598317   30.565728   28.821106   31.83376
# min      1.000000    1.000000    3.000000    0.00000
# 25%     23.000000   19.750000   24.750000   26.00000
# 50%     56.500000   50.500000   46.500000   60.50000
# 75%     72.250000   71.250000   73.000000   86.00000
# max    100.000000   99.000000  100.000000  100.00000

# %%
df[0::2].describe()
# Out:
#               Age     Height      Weight       Speed
# count   50.000000  50.000000   50.000000   50.000000
# mean    45.940000  46.700000   53.540000   52.900000
# std     29.918536  32.106487   26.561603   32.474323
# min      2.000000   2.000000    3.000000    0.000000
# 25%     19.750000  15.250000   35.500000   26.750000
# 50%     49.500000  48.500000   53.000000   62.000000
# 75%     71.000000  71.250000   73.000000   85.750000
# max    100.000000  99.000000  100.000000  100.000000

# %%
df.iloc[0]
# Out:
# Age       60
# Height     8
# Weight     5
# Speed     97
# Name: 0, dtype: int64

# %%
df.iloc[[0,1,2,3,4,5]]  #Prints 3 rows with index -0,1,2,3,4,
# Out:
#    Age  Height  Weight  Speed
# 0   60       8       5     97
# 1   77      54      38     97
# 2   23      67      99     71
# 3   68      98      43     73
# 4   65      20      67     69
# 5   32      45      38     90

# %%
df.sort_index()
# Out:
#     Age  Height  Weight  Speed
# 0    60       8       5     97
# 1    77      54      38     97
# 2    23      67      99     71
# 3    68      98      43     73
# 4    65      20      67     69
# ..  ...     ...     ...    ...
# 95   80      73      39     25
# 96   17       5      64     65
# 97   12      55      66     39
# 98   79      99      24     65
# 99   53      79       6     26
#
# [100 rows x 4 columns]
